# %%
# %matplotlib inline
import gym
env = gym.make("CartPole-v0")
env.reset()
# Out:
# array([-0.0050905 ,  0.02172408,  0.03039372, -0.00416163])

# %% [markdown]
# # Run Game (Random action)

# %%
episode_number = 100
reward_sum = 0
reward_list = []
for i in range(episode_number):
    env.render()
    action = env.action_space.sample()
    observation, reward, done, _ = env.step(action)
    reward_sum += 1
    if done:
        print("Reward for this episode ({}) was : {}".format(i, reward_sum))
        reward_sum = 0
        env.reset()
        reward_list.append(0)
    else:
        reward_list.append(1)
# Out:
# Reward for this episode (24) was : 25
# Reward for this episode (37) was : 13
# Reward for this episode (52) was : 15
# Reward for this episode (78) was : 26

# %%
print("Success rate : {}".format(sum(reward_list)/episode_number))
# print("Final Q-Table values")
# print(Q)
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 2))
plt.scatter(range(len(reward_list)), reward_list, color="blue")
plt.show()
# Out:
# Success rate : 0.96

# %% [markdown]
# # Run Game (Train with Q Networkk)

# %%
input_size = env.observation_space.shape[0]
output_size = env.action_space.n

# %%
import keras
from keras.models import Sequential, Model
from keras.layers import Input, Dense, Activation, Dropout
from keras.optimizers import Adam, SGD
from keras import metrics
# Out:
# Using TensorFlow backend.

# %% [markdown]
# NN : instead of Q-table

# %%
def get_model(input_size, output_size):
    input1 = Input(shape=(input_size,))
    out1 = Dense(16, input_shape=(input_size,), activation='relu')(input1)
    #out1 = Dropout(0.3)(out1)
    out1 = Dense(32, activation='relu')(out1)
    #out1 = Dropout(0.3)(out1)
    out1 = Dense(64, activation='relu')(out1)
    out1 = Dense(32, activation='relu')(out1)
    out1 = Dense(16, activation='relu')(out1)
    out1 = Dense(output_size, activation='softmax')(out1)
    model1 = Model(input1, out1) # input, output
    model1.summary()
    model1.compile(loss='mean_squared_error', 
                  optimizer=Adam(lr=0.001),  # , beta_1=0.9, beta_2=0.999, epsilon=1e-8),
                  metrics=[metrics.mean_squared_error])
    return model1
model = get_model(input_size, output_size)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 4)                 0
# _________________________________________________________________
# dense_7 (Dense)              (None, 16)                80
# _________________________________________________________________
# dense_8 (Dense)              (None, 32)                544
# _________________________________________________________________
# dense_9 (Dense)              (None, 64)                2112
# _________________________________________________________________
# dense_10 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_11 (Dense)             (None, 16)                528
# _________________________________________________________________
# dense_12 (Dense)             (None, 2)                 34
# =================================================================
# Total params: 5,378
# Trainable params: 5,378
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Q-network
# ![image.png](attachment:image.png)
#
# - https://www.inflearn.com/course/reinforcement-learning/lecture/5789
# - codes are re-written by keras (kwankiahn@gmail.com)

# %%
import numpy as np

# %%
episode_number = 100
reward_sum = 0
reward_list = []
dis = 0.9
aRandomList = []
rList = []
rList1 = []
print("input_size : {}, output_size : {}".format(input_size, output_size))

for i in range(episode_number):
    e = 1.0 / ((i / 10) + 1)
    rAll = 0
    step_count = 0
    s = env.reset()
    done = False
    
    # Q-Network training
    while not done:
        step_count += 1
        x = np.reshape(s, [1, input_size])
        # Choose an action by greedily (with e chance of fandom action) from the Q-network
        Qs = model.predict(x)
        if np.random.rand(1) < e:
            a = env.action_space.sample()
            aRandomList.append(1)
        else:
            a = np.argmax(Qs)
            aRandomList.append(0)
    
        # Get new state, reward from environment
        s1, reward, done, _ = env.step(action)
        if done:
            Qs[0, a] = -100
        else:
            x1 = np.reshape(s1, [1, input_size])
            Qs1 = model.predict(x1)
            Qs[0, a] = reward + dis * np.max(Qs1)
            
        print("Qs : {}".format(Qs))
        # Train out network using target and predicted Q values on each episode
        model.fit(x, Qs, epochs=1, batch_size=1, verbose=0)
        s = s1
        
    rList.append(step_count)
    print("Episode : {}, steps : {}".format(i, step_count))
    # If last 10's avg step are 500, it's good enough
    if len(rList) > 10 and np.mean(rList[-10:]) > 100:
        print("Good enough stop.")
        break
        
    # See our trained network in action
    print("Episode {} train done, See our trained network in action.".format(i))
    observation = env.reset()
    reward_sum = 0
    while True:
        env.render()
        x = np.reshape(observation, [1, input_size])
        Qs = model.predict(x)
        a = np.argmax(Qs)
        
        observation, reward, done, _ = env.step(a)
        reward_sum += reward
        if done:
            print("Total score : {}".format(reward_sum))
            rList1.append(reward_sum)
            break;
# Out:
# input_size : 4, output_size : 2
# WARNING:tensorflow:From C:\Users\pray4\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:2741: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From C:\Users\pray4\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# Qs : [[1.4577581 0.5009266]]
# Qs : [[1.4603575 0.5047203]]
# Qs : [[0.49275634 1.4620157 ]]
# Qs : [[0.48630458 1.4683297 ]]
# Qs : [[1.478091  0.5234812]]
# Qs : [[1.4840448  0.53001636]]
# Qs : [[0.46621293 1.4872304 ]]
# Qs : [[1.4942541  0.54124796]]
# Qs : [[-100.            0.54556143]]
# Episode : 0, steps : 9
# Episode 0 train done, See our trained network in action.
# Total score : 63.0
# Qs : [[1.4502624  0.49774456]]
# Qs : [[0.49860606 1.4576035 ]]
# Qs : [[0.4895024 1.4664308]]
# Qs : [[0.4794978 1.4760472]]
# Qs : [[1.4865949  0.53152955]]
# Qs : [[0.45676798 1.4977348 ]]
# Qs : [[0.4441206 1.5097452]]
# Qs : [[1.522632  0.5694872]]
# Qs : [[   0.41653246 -100.        ]]
# Episode : 1, steps : 9
# Episode 1 train done, See our trained network in action.
# Total score : 21.0
# Qs : [[0.4992065 1.4610308]]
# Qs : [[0.4887293 1.4687628]]
# Qs : [[1.4763308 0.5197701]]
# Qs : [[0.471987  1.4835747]]
# Qs : [[1.4908125 0.5359984]]
# Qs : [[1.4980514 0.5439501]]
# Qs : [[0.44808322 1.505328  ]]
# Qs : [[   0.43999276 -100.        ]]
# Episode : 2, steps : 8
# Episode 2 train done, See our trained network in action.
# Total score : 64.0
# Qs : [[1.4518139  0.49850696]]
# Qs : [[0.49928895 1.4565753 ]]
# Qs : [[0.49411577 1.4611056 ]]
# Qs : [[1.4654185 0.5107831]]
# Qs : [[1.4695749  0.51542157]]
# Qs : [[0.4800629 1.4736184]]
# Qs : [[0.47558498 1.4776525 ]]
# Qs : [[1.4817061 0.5288871]]
# Qs : [[1.4857639  0.53334534]]
# Qs : [[-100.           0.5378146]]
# Episode : 3, steps : 10
# Episode 3 train done, See our trained network in action.
# Total score : 22.0
# Qs : [[0.50418353 1.4536151 ]]
# Qs : [[0.50362945 1.4507791 ]]
# Qs : [[1.4562327 0.5014567]]
# Qs : [[0.49245852 1.4619408 ]]
# Qs : [[1.468015   0.51398206]]
# Qs : [[1.4744624 0.520743 ]]
# Qs : [[0.472082  1.4812171]]
# Qs : [[1.4883218  0.53546464]]
# Qs : [[0.45665747 1.4957311 ]]
# Qs : [[-100.           0.5516223]]
# Episode : 4, steps : 10
# Episode 4 train done, See our trained network in action.
# Total score : 33.0
# Qs : [[1.4514188  0.49807867]]
# Qs : [[1.4590949  0.50274116]]
# Qs : [[0.48857406 1.4671437 ]]
# Qs : [[0.47937253 1.4757506 ]]
# Qs : [[0.46968022 1.4849277 ]]
# Qs : [[0.4593662 1.4946777]]
# Qs : [[1.5049905  0.55156225]]
# Qs : [[   0.4369586 -100.       ]]
# Episode : 5, steps : 8
# Episode 5 train done, See our trained network in action.
# Total score : 35.0
# Qs : [[1.4527806  0.49982625]]
# Qs : [[1.4591129 0.5026721]]
# Qs : [[1.4655962 0.5096313]]
# Qs : [[0.48321587 1.4721456 ]]
# Qs : [[1.4788215 0.5240416]]
# Qs : [[1.4856495 0.5314308]]
# Qs : [[1.4926574  0.53898793]]
# Qs : [[1.4998004  0.54674643]]
# Qs : [[0.44534174 1.5071477 ]]
# Qs : [[0.43714222 1.514772  ]]
# Qs : [[-100.            0.57137555]]
# Episode : 6, steps : 11
# Episode 6 train done, See our trained network in action.
# Total score : 42.0
# Qs : [[0.5014995 1.4515147]]
# Qs : [[0.49769628 1.4593252 ]]
# Qs : [[1.4675044 0.5113375]]
# Qs : [[0.47943524 1.4762112 ]]
# Qs : [[1.4854251 0.5303547]]
# Qs : [[0.4593365 1.4951406]]
# Qs : [[1.5053872  0.55154186]]
# Qs : [[1.5161252  0.56295574]]
# Qs : [[0.42512825 1.5273134 ]]
# Qs : [[   0.41264677 -100.        ]]
# Episode : 7, steps : 10
# Episode 7 train done, See our trained network in action.
# Total score : 13.0
# Qs : [[0.5002324 1.4543651]]
# Qs : [[0.49576902 1.4620442 ]]
# Qs : [[1.4693677 0.5126331]]
# Qs : [[0.47939575 1.4763161 ]]
# Qs : [[1.4833142  0.52827525]]
# Qs : [[1.4903923 0.5359922]]
# Qs : [[0.4561902 1.4975935]]
# Qs : [[0.44818196 1.5049967 ]]
# Qs : [[0.43993467 1.5125962 ]]
# Qs : [[   0.4314624 -100.       ]]
# Episode : 8, steps : 10
# Episode 8 train done, See our trained network in action.
# Total score : 50.0
# Qs : [[0.5004448 1.4507197]]
# Qs : [[0.4998327 1.4565312]]
# Qs : [[0.49379304 1.4617454 ]]
# Qs : [[0.48796955 1.46695   ]]
# Qs : [[0.48211393 1.4722457 ]]
# Qs : [[0.47614005 1.4777046 ]]
# Qs : [[0.46992642 1.4834574 ]]
# Qs : [[0.46334755 1.4895875 ]]
# Qs : [[0.45631617 1.4961692 ]]
# Qs : [[-100.           0.5512491]]
# Episode : 9, steps : 10
# Episode 9 train done, See our trained network in action.
# Total score : 8.0
# Qs : [[0.49951625 1.4504566 ]]
# Qs : [[0.49872488 1.4562155 ]]
# Qs : [[0.49236935 1.4634601 ]]
# Qs : [[0.4840368 1.4711075]]
# Qs : [[0.4754381 1.4791831]]
# Qs : [[1.4877045 0.533609 ]]
# Qs : [[1.496628 0.543094]]
# Qs : [[0.4469895 1.5059472]]
# Qs : [[   0.43659288 -100.        ]]
# Episode : 10, steps : 9
# Episode 10 train done, See our trained network in action.
# Total score : 10.0
# Qs : [[1.4566971 0.5029431]]
# Qs : [[0.49308065 1.4616624 ]]
# Qs : [[1.4677403 0.5124407]]
# Qs : [[0.48130938 1.4735045 ]]
# Qs : [[0.47479916 1.479444  ]]
# Qs : [[0.4680755 1.4856004]]
# Qs : [[1.4920721 0.5389189]]
# Qs : [[   0.45423144 -100.        ]]
# Episode : 11, steps : 8
# Episode 11 train done, See our trained network in action.
# Total score : 10.0
# Qs : [[0.4993626 1.4531734]]
# Qs : [[0.49778074 1.4550351 ]]
# Qs : [[0.49604255 1.4585676 ]]
# Qs : [[0.49215004 1.4621829 ]]
# Qs : [[0.48812044 1.4658298 ]]
# Qs : [[1.4694387 0.5159013]]
# Qs : [[1.4732007 0.5199741]]
# Qs : [[0.475876  1.4769596]]
# Qs : [[   0.4716692 -100.       ]]
# Episode : 12, steps : 9
# Episode 12 train done, See our trained network in action.
# Total score : 29.0
# Qs : [[1.4533939 0.4989147]]
# Qs : [[1.4541042  0.49550125]]
# Qs : [[1.4535905 0.4945547]]
# Qs : [[1.4524851  0.49508014]]
# Qs : [[1.4510852 0.4962594]]
# Qs : [[1.4502497 0.4977701]]
# Qs : [[1.4515395 0.4992326]]
# Qs : [[0.49936196 1.4529313 ]]
# Qs : [[0.49801823 1.4543252 ]]
# Qs : [[   0.4966245 -100.       ]]
# Episode : 13, steps : 10
# Episode 13 train done, See our trained network in action.
# Total score : 13.0
# Qs : [[1.4579242 0.4913192]]
# Qs : [[0.5094447 1.4605912]]
# Qs : [[1.4606682  0.48744935]]
# Qs : [[1.4606926 0.4872373]]
# Qs : [[0.5129404 1.4606622]]
# Qs : [[1.4608765  0.48703018]]
# Qs : [[1.4610234  0.48686555]]
# Qs : [[0.5132976 1.4612677]]
# Qs : [[   0.51353693 -100.        ]]
# Episode : 14, steps : 9
# Episode 14 train done, See our trained network in action.
# Total score : 9.0
# Qs : [[1.4623005  0.48465088]]
# Qs : [[1.463965   0.48540485]]
# Qs : [[1.4668498 0.4835605]]
# Qs : [[0.51977247 1.4697956 ]]
# Qs : [[0.52313197 1.4716443 ]]
# Qs : [[1.4734277  0.47477725]]
# Qs : [[1.4752792  0.47273797]]
# Qs : [[1.4773484 0.4706311]]
# Qs : [[1.4794822  0.46829695]]
# Qs : [[1.4818184 0.4659046]]
# Qs : [[-100.            0.46328756]]
# Episode : 15, steps : 11
# Episode 15 train done, See our trained network in action.
# Total score : 10.0
# Qs : [[1.4682186  0.47952074]]
# Qs : [[1.4695684  0.47983673]]
# Qs : [[1.4722254  0.47837204]]
# Qs : [[1.4732003  0.47559536]]
# Qs : [[1.4738598 0.4745712]]
# Qs : [[0.525982  1.4740725]]
# Qs : [[1.4741172  0.47380674]]
# Qs : [[0.5262489 1.4740264]]
# Qs : [[-100.           0.4738855]]
# Episode : 16, steps : 9
# Episode 16 train done, See our trained network in action.
# Total score : 8.0
# Qs : [[1.469148  0.4757354]]
# Qs : [[0.52119124 1.4685719 ]]
# Qs : [[1.4692593  0.47976378]]
# Qs : [[1.4698539  0.47871703]]
# Qs : [[0.52212477 1.4684231 ]]
# Qs : [[1.4670246  0.48011255]]
# Qs : [[1.4657418 0.4815593]]
# Qs : [[1.4644134  0.48287073]]
# Qs : [[1.4630232 0.4842496]]
# Qs : [[-100.            0.48568398]]
# Episode : 17, steps : 10
# Episode 17 train done, See our trained network in action.
# Total score : 10.0
# Qs : [[1.4687778  0.47386175]]
# Qs : [[1.4689301  0.47927684]]
# Qs : [[1.4693308  0.47916788]]
# Qs : [[1.4676672  0.47877476]]
# Qs : [[1.464901   0.48054516]]
# Qs : [[1.461997   0.48319304]]
# Qs : [[1.4599957  0.48592123]]
# Qs : [[-100.           0.4876499]]
# Episode : 18, steps : 8
# Episode 18 train done, See our trained network in action.
# Total score : 8.0
# Qs : [[1.471113   0.46864522]]
# Qs : [[1.4687375 0.4769794]]
# Qs : [[1.4663     0.48000085]]
# Qs : [[1.4606225 0.4831731]]
# Qs : [[1.4549091 0.4896633]]
# Qs : [[1.4507753 0.4961817]]
# Qs : [[1.4523315  0.49985993]]
# Qs : [[1.455368  0.5031905]]
# Qs : [[0.49352533 1.4584419 ]]
# Qs : [[   0.4899905 -100.       ]]
# Episode : 19, steps : 10
# Episode 19 train done, See our trained network in action.
# Total score : 10.0
# Qs : [[1.472385   0.46311826]]
# Qs : [[1.4682509  0.47422096]]
# Qs : [[0.52134186 1.4627819 ]]
# Qs : [[0.5144855 1.4578402]]
# Qs : [[0.509042  1.4549184]]
# Qs : [[0.50578684 1.4526011 ]]
# Qs : [[1.4500701  0.49691802]]
# Qs : [[1.4516034  0.49947864]]
# Qs : [[-100.           0.5013184]]
# Episode : 20, steps : 9
# Episode 20 train done, See our trained network in action.
# Total score : 10.0
# Qs : [[1.4809463  0.45182398]]
# Qs : [[1.4722635 0.4652962]]
# Qs : [[0.52505845 1.4641985 ]]
# Qs : [[1.4565288  0.48523912]]
# Qs : [[1.4534183  0.49255744]]
# Qs : [[1.4516051  0.49564958]]
# Qs : [[1.451169   0.49819362]]
# Qs : [[0.49863148 1.4542406 ]]
# Qs : [[0.49506262 1.457549  ]]
# Qs : [[-100.           0.5087934]]
# Episode : 21, steps : 10
# Episode 21 train done, See our trained network in action.
# Total score : 10.0
# Qs : [[0.5575484 1.4845766]]
# Qs : [[1.4708081  0.46263003]]
# Qs : [[1.4612623  0.47748023]]
# Qs : [[1.4525411  0.48797658]]
# Qs : [[1.4534081  0.49756968]]
# Qs : [[0.49597874 1.4572074 ]]
# Qs : [[0.49135518 1.4610585 ]]
# Qs : [[0.48694387 1.465117  ]]
# Qs : [[0.48234156 1.4694679 ]]
# Qs : [[   0.47740042 -100.        ]]
# Episode : 22, steps : 10
# Episode 22 train done, See our trained network in action.
# Total score : 9.0
# Qs : [[1.4822371  0.45186096]]
# Qs : [[1.4699663  0.46335608]]
# Qs : [[1.4597373  0.47637984]]
# Qs : [[1.4534284  0.48806125]]
# Qs : [[1.4510179  0.49467847]]
# Qs : [[1.4540206 0.4994206]]
# Qs : [[1.4556167  0.50303555]]
# Qs : [[   0.49504593 -100.        ]]
# Episode : 23, steps : 8
# Episode 23 train done, See our trained network in action.
# Total score : 10.0
# Qs : [[1.492498   0.44106653]]
# Qs : [[1.4838395  0.45073804]]
# Qs : [[1.4764537  0.45984387]]
# Qs : [[0.5326619 1.4714537]]
# Qs : [[1.4688324  0.47404298]]
# Qs : [[1.4670808  0.47640345]]
# Qs : [[1.4664285  0.47736993]]
# Qs : [[-100.            0.47762713]]
# Episode : 24, steps : 8
# Episode 24 train done, See our trained network in action.
# Total score : 9.0
# Qs : [[1.506458   0.42339763]]
# Qs : [[1.4964244  0.43836695]]
# Qs : [[1.4827614  0.44963217]]
# Qs : [[1.4693545 0.4647344]]
# Qs : [[1.4613597  0.47934774]]
# Qs : [[1.4585114  0.48818067]]
# Qs : [[1.4566896 0.4911291]]
# Qs : [[1.4548198  0.49314657]]
# Qs : [[1.45282    0.49520788]]
# Qs : [[0.50262284 1.4507705 ]]
# Qs : [[-100.            0.49966934]]
# Episode : 25, steps : 11
# Episode 25 train done, See our trained network in action.
# Total score : 9.0
# Qs : [[0.57793105 1.5018289 ]]
# Qs : [[1.4888463  0.44392443]]
# Qs : [[1.4721384  0.45824566]]
# Qs : [[1.4585359 0.4768845]]
# Qs : [[1.4526495  0.49155915]]
# Qs : [[1.4519554  0.49766088]]
# Qs : [[0.49741578 1.4561349 ]]
# Qs : [[0.49237102 1.4607333 ]]
# Qs : [[-100.           0.5131606]]
# Episode : 26, steps : 9
# Episode 26 train done, See our trained network in action.
# Total score : 9.0
# Qs : [[1.5004342  0.42526698]]
# Qs : [[1.4815886  0.44491392]]
# Qs : [[1.4611003 0.4668689]]
# Qs : [[1.4536297 0.4896467]]
# Qs : [[0.4941811 1.4615473]]
# Qs : [[0.48553106 1.4671214 ]]
# Qs : [[0.47968757 1.4725808 ]]
# Qs : [[   0.47354978 -100.        ]]
# Episode : 27, steps : 8
# Episode 27 train done, See our trained network in action.
# Total score : 10.0
# Qs : [[1.4948729 0.4273374]]
# Qs : [[1.4773482 0.4496141]]
# Qs : [[1.4573078  0.46907842]]
# Qs : [[1.4559304  0.49141055]]
# Qs : [[1.4611133 0.5060362]]
# Qs : [[0.48807678 1.4647825 ]]
# Qs : [[0.48386416 1.4683056 ]]
# Qs : [[0.47994083 1.4718981 ]]
# Qs : [[0.47581795 1.4753207 ]]
# Qs : [[   0.47178006 -100.        ]]
# Episode : 28, steps : 10
# Episode 28 train done, See our trained network in action.
# Total score : 10.0
# Qs : [[1.5016552  0.41437277]]
# Qs : [[0.55858773 1.481594  ]]
# Qs : [[1.4614499  0.46411303]]
# Qs : [[1.4515607  0.48611367]]
# Qs : [[0.4995586 1.4553183]]
# Qs : [[0.4950848 1.4577157]]
# Qs : [[0.49241212 1.459756  ]]
# Qs : [[0.4901238 1.4619517]]
# Qs : [[   0.4876178 -100.       ]]
# Episode : 29, steps : 9
# Episode 29 train done, See our trained network in action.
# Total score : 9.0
# Qs : [[0.589691  1.5080746]]
# Qs : [[1.4887062  0.43483526]]
# Qs : [[1.4714197  0.45533592]]
# Qs : [[1.4613663  0.47433746]]
# Qs : [[1.4563137 0.4852203]]
# Qs : [[1.4541619  0.49142534]]
# Qs : [[1.4531752  0.49378678]]
# Qs : [[-100.            0.49527058]]
# Episode : 30, steps : 8
# Episode 30 train done, See our trained network in action.
# Total score : 9.0
# Qs : [[1.5149268 0.4014899]]
# Qs : [[1.4996027  0.42775866]]
# Qs : [[1.483844   0.44460112]]
# Qs : [[1.4711382  0.46184057]]
# Qs : [[1.4627681  0.47595137]]
# Qs : [[1.4565722  0.48542598]]
# Qs : [[1.4516716 0.4930277]]
# Qs : [[1.4529082  0.49847037]]
# Qs : [[0.49631217 1.456588  ]]
# Qs : [[   0.4921362 -100.       ]]
# Episode : 31, steps : 10
# Episode 31 train done, See our trained network in action.
# Total score : 9.0
# Qs : [[0.6013382 1.5203973]]
# Qs : [[1.5058831 0.420813 ]]
# Qs : [[1.4920386 0.4363818]]
# Qs : [[1.4805373  0.45128554]]
# Qs : [[1.4733254  0.46393517]]
# Qs : [[1.4675995  0.47216052]]
# Qs : [[1.4621738  0.47811863]]
# Qs : [[1.4600897 0.4839212]]
# Qs : [[-100.            0.48698458]]
# Episode : 32, steps : 9
# Episode 32 train done, See our trained network in action.
# Total score : 8.0
# Qs : [[1.5320691  0.37656924]]
# Qs : [[1.517433   0.40966925]]
# Qs : [[1.500846   0.42607868]]
# Qs : [[1.4860971  0.44454312]]
# Qs : [[1.4724735  0.46121037]]
# Qs : [[1.4605901  0.47623336]]
# Qs : [[1.4545314  0.49016243]]
# Qs : [[1.4513141  0.49550778]]
# Qs : [[1.4518385  0.49907696]]
# Qs : [[   0.49745175 -100.        ]]
# Episode : 33, steps : 10
# Episode 33 train done, See our trained network in action.
# Total score : 9.0
# Qs : [[0.6315525 1.5370746]]
# Qs : [[1.5166993 0.4032096]]
# Qs : [[1.498442  0.4253796]]
# Qs : [[1.4821955  0.44557402]]
# Qs : [[1.4690378  0.46359396]]
# Qs : [[1.4607061 0.4781531]]
# Qs : [[1.4592702 0.4871988]]
# Qs : [[1.4583338  0.48900512]]
# Qs : [[1.4571853 0.4900863]]
# Qs : [[-100.            0.49123484]]
# Episode : 34, steps : 10
# Episode 34 train done, See our trained network in action.
# Total score : 9.0
# Qs : [[1.541692   0.36332715]]
# Qs : [[1.5230906  0.39766407]]
# Qs : [[1.5044913 0.4181231]]
# Qs : [[1.486995   0.43902388]]
# Qs : [[0.541481  1.4718397]]
# Qs : [[1.4608171  0.47614592]]
# Qs : [[1.4553863  0.48837864]]
# Qs : [[1.4523168  0.49462217]]
# Qs : [[1.450683   0.49803123]]
# Qs : [[   0.49866492 -100.        ]]
# Episode : 35, steps : 10
# Episode 35 train done, See our trained network in action.
# Total score : 9.0
# Qs : [[1.5435874  0.36186096]]
# Qs : [[0.6054458 1.5252042]]
# Qs : [[1.5062951 0.4158091]]
# Qs : [[1.4884192  0.43698448]]
# Qs : [[1.4731528 0.4565841]]
# Qs : [[1.4644026 0.4735575]]
# Qs : [[0.5168438 1.4603746]]
# Qs : [[1.4592754  0.48788285]]
# Qs : [[1.4585882  0.48911858]]
# Qs : [[-100.            0.48983884]]
# Episode : 36, steps : 10
# Episode 36 train done, See our trained network in action.
# Total score : 9.0
# Qs : [[1.5485034  0.36158282]]
# Qs : [[1.5274057  0.39010283]]
# Qs : [[1.5055653  0.41373226]]
# Qs : [[1.485566  0.4381667]]
# Qs : [[1.4695557  0.46057725]]
# Qs : [[1.4599311 0.4784091]]
# Qs : [[1.4547385 0.4892847]]
# Qs : [[1.4521347 0.4953568]]
# Qs : [[-100.            0.49821517]]
# Episode : 37, steps : 9
# Episode 37 train done, See our trained network in action.
# Total score : 10.0
# Qs : [[1.559188   0.33998823]]
# Qs : [[1.5333349  0.37799504]]
# Qs : [[1.5075811 0.4070078]]
# Qs : [[1.4845374  0.43617252]]
# Qs : [[1.465558   0.46200067]]
# Qs : [[1.4523989  0.48299348]]
# Qs : [[1.4555365  0.49787083]]
# Qs : [[0.4930974 1.461493 ]]
# Qs : [[-100.           0.5139229]]
# Episode : 38, steps : 9
# Episode 38 train done, See our trained network in action.
# Total score : 8.0
# Qs : [[1.5778635 0.3135084]]
# Qs : [[1.5470316  0.35661396]]
# Qs : [[1.5107367 0.3911277]]
# Qs : [[1.4802824 0.4311296]]
# Qs : [[1.456738   0.46605942]]
# Qs : [[1.4616758  0.49309158]]
# Qs : [[0.48607838 1.4678036 ]]
# Qs : [[0.47938594 1.4729575 ]]
# Qs : [[   0.47365665 -100.        ]]
# Episode : 39, steps : 9
# Episode 39 train done, See our trained network in action.
# Total score : 8.0
# Qs : [[1.5992308 0.2754315]]
# Qs : [[1.5663054 0.3310575]]
# Qs : [[1.5315456  0.36678612]]
# Qs : [[1.4983042  0.40522343]]
# Qs : [[1.470294   0.44072637]]
# Qs : [[1.4513527 0.4719974]]
# Qs : [[1.4585937  0.49272934]]
# Qs : [[1.4622303 0.5058074]]
# Qs : [[   0.48894742 -100.        ]]
# Episode : 40, steps : 9
# Episode 40 train done, See our trained network in action.
# Total score : 9.0
# Qs : [[0.77757454 1.6412657 ]]
# Qs : [[1.6152889  0.28417736]]
# Qs : [[1.5903296  0.31040457]]
# Qs : [[1.5701076  0.33587652]]
# Qs : [[1.5545198 0.3556889]]
# Qs : [[1.5470233  0.37130475]]
# Qs : [[1.5435625 0.3786505]]
# Qs : [[1.5433292  0.38079476]]
# Qs : [[1.5473691  0.37878126]]
# Qs : [[-100.            0.37163717]]
# Episode : 41, steps : 10
# Episode 41 train done, See our trained network in action.
# Total score : 9.0
# Qs : [[1.6748188  0.21670258]]
# Qs : [[1.6429254  0.25933835]]
# Qs : [[1.6024104 0.2963899]]
# Qs : [[0.65677136 1.5612649 ]]
# Qs : [[1.5189073 0.3905704]]
# Qs : [[0.5644298 1.4895109]]
# Qs : [[1.4753753 0.4635918]]
# Qs : [[1.471401  0.4747106]]
# Qs : [[-100.           0.4778549]]
# Episode : 42, steps : 9
# Episode 42 train done, See our trained network in action.
# Total score : 8.0
# Qs : [[1.6234144  0.24491888]]
# Qs : [[1.5782043 0.3112024]]
# Qs : [[1.5276629  0.36207354]]
# Qs : [[0.58076173 1.4884104 ]]
# Qs : [[1.4667753 0.4622305]]
# Qs : [[1.4614596  0.48342046]]
# Qs : [[1.4574392 0.4886261]]
# Qs : [[1.4511476 0.4931562]]
# Qs : [[0.49967507 1.4557694 ]]
# Qs : [[   0.49241474 -100.        ]]
# Episode : 43, steps : 10
# Episode 43 train done, See our trained network in action.
# Total score : 9.0
# Qs : [[1.6218731  0.24062338]]
# Qs : [[1.5680313  0.30871347]]
# Qs : [[1.5141404  0.36870137]]
# Qs : [[1.4751049  0.42852342]]
# Qs : [[1.461046   0.47229308]]
# Qs : [[1.4581637  0.48778054]]
# Qs : [[1.4561279  0.49090847]]
# Qs : [[1.4532261  0.49314547]]
# Qs : [[1.450024  0.4962192]]
# Qs : [[-100.            0.49980676]]
# Episode : 44, steps : 10
# Episode 44 train done, See our trained network in action.
# Total score : 9.0
# Qs : [[1.6276151  0.22886418]]
# Qs : [[1.571414 0.301754]]
# Qs : [[1.512618   0.36453006]]
# Qs : [[1.4714823  0.42972156]]
# Qs : [[1.4557867 0.4758257]]
# Qs : [[1.4515591 0.4938789]]
# Qs : [[1.4501935  0.49875024]]
# Qs : [[0.49965593 1.4517663 ]]
# Qs : [[0.4978996 1.4544055]]
# Qs : [[   0.49504706 -100.        ]]
# Episode : 45, steps : 10
# Episode 45 train done, See our trained network in action.
# Total score : 10.0
# Qs : [[1.6260527  0.22172342]]
# Qs : [[1.5729127 0.3015661]]
# Qs : [[1.519638   0.36034596]]
# Qs : [[1.4804028 0.418938 ]]
# Qs : [[0.5366728 1.4598777]]
# Qs : [[1.4525094  0.48797193]]
# Qs : [[1.450156  0.4966888]]
# Qs : [[1.4509281  0.49962547]]
# Qs : [[   0.49898425 -100.        ]]
# Episode : 46, steps : 9
# Episode 46 train done, See our trained network in action.
# Total score : 10.0
# Qs : [[1.6717798  0.17530361]]
# Qs : [[1.6221682  0.25108716]]
# Qs : [[1.5675309  0.30627552]]
# Qs : [[1.5106713  0.36655393]]
# Qs : [[1.4770973  0.42973706]]
# Qs : [[1.4590812 0.4676761]]
# Qs : [[1.4551667 0.4884744]]
# Qs : [[1.4521238 0.4935027]]
# Qs : [[-100.            0.49709556]]
# Episode : 47, steps : 9
# Episode 47 train done, See our trained network in action.
# Total score : 10.0
# Qs : [[1.7035381 0.1477888]]
# Qs : [[1.6374342  0.21708797]]
# Qs : [[1.5805281  0.29145455]]
# Qs : [[1.516537   0.35500845]]
# Qs : [[1.4787112 0.4265948]]
# Qs : [[1.4565275 0.4688981]]
# Qs : [[1.4525151  0.49342784]]
# Qs : [[0.50282323 1.4526329 ]]
# Qs : [[0.5029459 1.4519475]]
# Qs : [[-100.            0.49794757]]
# Episode : 48, steps : 10
# Episode 48 train done, See our trained network in action.
# Total score : 10.0
# Qs : [[1.6946437  0.14803974]]
# Qs : [[1.6306103  0.22610424]]
# Qs : [[1.5666786  0.29796913]]
# Qs : [[1.5033728  0.36916885]]
# Qs : [[0.5604735 1.4639993]]
# Qs : [[1.4514046  0.48495165]]
# Qs : [[1.4508797  0.49858665]]
# Qs : [[1.4508452  0.49929133]]
# Qs : [[   0.49879915 -100.        ]]
# Episode : 49, steps : 9
# Episode 49 train done, See our trained network in action.
# Total score : 9.0
# Qs : [[1.7370334  0.10880327]]
# Qs : [[1.6530185  0.17841083]]
# Qs : [[1.5910115  0.27227575]]
# Qs : [[1.5211725  0.34079212]]
# Qs : [[0.58176315 1.4774938 ]]
# Qs : [[1.452371   0.46856913]]
# Qs : [[1.4518689  0.49708408]]
# Qs : [[1.4511163  0.49784136]]
# Qs : [[1.4501144  0.49859038]]
# Qs : [[-100.           0.4997209]]
# Episode : 50, steps : 10
# Episode 50 train done, See our trained network in action.
# Total score : 9.0
# Qs : [[0.9098721 1.7531953]]
# Qs : [[1.6670234  0.16319162]]
# Qs : [[1.6025633  0.25842768]]
# Qs : [[1.5275252  0.32963365]]
# Qs : [[1.4775382  0.41250813]]
# Qs : [[1.4510714 0.4683794]]
# Qs : [[1.4510206  0.49893504]]
# Qs : [[1.4508694  0.49898314]]
# Qs : [[0.49890962 1.4524212 ]]
# Qs : [[   0.4971635 -100.       ]]
# Episode : 51, steps : 10
# Episode 51 train done, See our trained network in action.
# Total score : 9.0
# Qs : [[1.7616705  0.08725229]]
# Qs : [[1.6752982  0.15145263]]
# Qs : [[1.607243   0.24568029]]
# Qs : [[1.5420768  0.32186022]]
# Qs : [[1.4978914  0.39369574]]
# Qs : [[1.4664372  0.44344956]]
# Qs : [[1.4516292 0.4782212]]
# Qs : [[1.451832  0.4980788]]
# Qs : [[1.4511573 0.4978975]]
# Qs : [[-100.           0.4983648]]
# Episode : 52, steps : 10
# Episode 52 train done, See our trained network in action.
# Total score : 10.0
# Qs : [[1.7925106  0.06236717]]
# Qs : [[1.7169191  0.11761605]]
# Qs : [[1.655323   0.20135431]]
# Qs : [[1.5851868  0.26992866]]
# Qs : [[0.6524677 1.5214999]]
# Qs : [[1.4727014  0.42050803]]
# Qs : [[1.4509622  0.47433472]]
# Qs : [[1.4501896 0.4990172]]
# Qs : [[   0.4996439 -100.       ]]
# Episode : 53, steps : 9
# Episode 53 train done, See our trained network in action.
# Total score : 8.0
# Qs : [[1.7987295  0.05994818]]
# Qs : [[1.7245234  0.10965425]]
# Qs : [[1.6599131  0.18980841]]
# Qs : [[1.5891354  0.26073667]]
# Qs : [[1.535053   0.33737594]]
# Qs : [[1.4895723 0.3980553]]
# Qs : [[1.4611807  0.45010844]]
# Qs : [[1.4518338 0.4819905]]
# Qs : [[-100.            0.49785277]]
# Episode : 54, steps : 9
# Episode 54 train done, See our trained network in action.
# Total score : 9.0
# Qs : [[1.8241541  0.04063084]]
# Qs : [[1.7717321  0.08131571]]
# Qs : [[0.8618301 1.7294905]]
# Qs : [[1.6732256  0.18601473]]
# Qs : [[1.6138641  0.24603714]]
# Qs : [[1.5700147  0.30877447]]
# Qs : [[0.6448813 1.529091 ]]
# Qs : [[-100.            0.40610176]]
# Episode : 55, steps : 8
# Episode 55 train done, See our trained network in action.
# Total score : 10.0
# Qs : [[1.8493059  0.02766208]]
# Qs : [[1.7951187  0.06311028]]
# Qs : [[1.691614   0.12938474]]
# Qs : [[1.5831611  0.25458053]]
# Qs : [[1.4707791  0.38139862]]
# Qs : [[1.4502714 0.4952528]]
# Qs : [[0.49955744 1.4531728 ]]
# Qs : [[0.4958123 1.456331 ]]
# Qs : [[-100.            0.50808835]]
# Episode : 56, steps : 9
# Episode 56 train done, See our trained network in action.
# Total score : 8.0
# Qs : [[1.7757432  0.06226839]]
# Qs : [[1.6560949  0.14267592]]
# Qs : [[1.51845    0.27841076]]
# Qs : [[1.4524797  0.43526348]]
# Qs : [[0.496772  1.4572035]]
# Qs : [[0.49090275 1.4620363 ]]
# Qs : [[0.48577103 1.4661419 ]]
# Qs : [[   0.48116216 -100.        ]]
# Episode : 57, steps : 8
# Episode 57 train done, See our trained network in action.
# Total score : 10.0
# Qs : [[1.7948898  0.05627969]]
# Qs : [[1.6993977 0.1172459]]
# Qs : [[1.5447028  0.22308014]]
# Qs : [[1.4523634  0.39402774]]
# Qs : [[0.4974768 1.4559073]]
# Qs : [[0.49355313 1.4589489 ]]
# Qs : [[0.4902989 1.4618282]]
# Qs : [[0.48707613 1.46512   ]]
# Qs : [[0.48339996 1.4685243 ]]
# Qs : [[   0.47959003 -100.        ]]
# Episode : 58, steps : 10
# Episode 58 train done, See our trained network in action.
# Total score : 9.0
# Qs : [[1.7879852  0.05576677]]
# Qs : [[1.6859928  0.12312122]]
# Qs : [[1.5283413  0.23481892]]
# Qs : [[1.4512181 0.4073907]]
# Qs : [[0.49892405 1.4526519 ]]
# Qs : [[0.4977228 1.454069 ]]
# Qs : [[0.49612075 1.4558829 ]]
# Qs : [[0.4940989 1.4579723]]
# Qs : [[   0.4917634 -100.       ]]
# Episode : 59, steps : 9
# Episode 59 train done, See our trained network in action.
# Total score : 8.0
# Qs : [[1.8029693  0.04687525]]
# Qs : [[1.7113113 0.1059096]]
# Qs : [[1.5541962  0.20549117]]
# Qs : [[1.4502867  0.37701556]]
# Qs : [[1.4503562  0.49963304]]
# Qs : [[1.4508961 0.5002128]]
# Qs : [[0.49918184 1.4514222 ]]
# Qs : [[   0.4985772 -100.       ]]
# Episode : 60, steps : 8
# Episode 60 train done, See our trained network in action.
# Total score : 10.0
# Qs : [[1.8284509  0.03413805]]
# Qs : [[1.764448   0.07782547]]
# Qs : [[1.6465145  0.14731044]]
# Qs : [[1.4827497 0.2752233]]
# Qs : [[1.4515166 0.454912 ]]
# Qs : [[1.4518551  0.49820244]]
# Qs : [[0.50233996 1.4516505 ]]
# Qs : [[1.451419   0.49789372]]
# Qs : [[0.50184125 1.4511585 ]]
# Qs : [[-100.            0.49847907]]
# Episode : 61, steps : 10
# Episode 61 train done, See our trained network in action.
# Total score : 9.0
# Qs : [[1.8447284  0.02649666]]
# Qs : [[1.794539   0.06001609]]
# Qs : [[0.8856375 1.7019444]]
# Qs : [[0.7820853 1.5476375]]
# Qs : [[1.4511964  0.39364007]]
# Qs : [[1.4518245 0.4984057]]
# Qs : [[1.4514102 0.4980957]]
# Qs : [[1.4508122 0.4985179]]
# Qs : [[-100.           0.4991822]]
# Episode : 62, steps : 9
# Episode 62 train done, See our trained network in action.
# Total score : 11.0
# Qs : [[1.8440794  0.02773691]]
# Qs : [[1.7916404  0.06181587]]
# Qs : [[1.6932566  0.11939456]]
# Qs : [[1.5436788  0.22690704]]
# Qs : [[1.4508939 0.3892564]]
# Qs : [[1.4500992  0.49746233]]
# Qs : [[0.49962467 1.4508814 ]]
# Qs : [[0.4988139 1.4518203]]
# Qs : [[   0.4977606 -100.       ]]
# Episode : 63, steps : 9
# Episode 63 train done, See our trained network in action.
# Total score : 9.0
# Qs : [[1.850209   0.02420461]]
# Qs : [[1.8086541  0.05422208]]
# Qs : [[1.7337317  0.09928621]]
# Qs : [[1.6278932 0.1802798]]
# Qs : [[1.5057123 0.29392  ]]
# Qs : [[1.4506869  0.42479843]]
# Qs : [[1.4503088  0.49868375]]
# Qs : [[0.4994845 1.4505043]]
# Qs : [[0.49954453 1.4511181 ]]
# Qs : [[-100.            0.50112236]]
# Episode : 64, steps : 10
# Episode 64 train done, See our trained network in action.
# Total score : 10.0
# Qs : [[0.986375  1.8726369]]
# Qs : [[1.8521035  0.02965023]]
# Qs : [[1.815672   0.05178936]]
# Qs : [[1.764027   0.09093699]]
# Qs : [[1.6938028  0.14592728]]
# Qs : [[1.6014683 0.2198247]]
# Qs : [[1.4973686 0.3153269]]
# Qs : [[1.4519323 0.4259248]]
# Qs : [[1.4531108  0.49370342]]
# Qs : [[0.49597114 1.453486  ]]
# Qs : [[   0.49588427 -100.        ]]
# Episode : 65, steps : 11
# Episode 65 train done, See our trained network in action.
# Total score : 9.0
# Qs : [[1.8776124  0.01108006]]
# Qs : [[1.8617709  0.02396768]]
# Qs : [[1.8338356  0.04083895]]
# Qs : [[1.7948667 0.0705   ]]
# Qs : [[1.7420357  0.11158291]]
# Qs : [[1.6710443 0.1668187]]
# Qs : [[1.5786062 0.239215 ]]
# Qs : [[1.4903818 0.3336162]]
# Qs : [[1.4527941  0.42534983]]
# Qs : [[-100.            0.48745587]]
# Episode : 66, steps : 10
# Episode 66 train done, See our trained network in action.
# Total score : 9.0
# Qs : [[1.8876706  0.00647049]]
# Qs : [[1.8759425  0.01518951]]
# Qs : [[1.8509176  0.02984458]]
# Qs : [[1.7997198 0.0610371]]
# Qs : [[1.7142466  0.12474579]]
# Qs : [[1.5659442 0.2294584]]
# Qs : [[1.4543983 0.4038045]]
# Qs : [[0.49543163 1.4526527 ]]
# Qs : [[0.49726805 1.4524047 ]]
# Qs : [[   0.49716863 -100.        ]]
# Episode : 67, steps : 10
# Episode 67 train done, See our trained network in action.
# Total score : 10.0
# Qs : [[1.8689089  0.01337863]]
# Qs : [[1.8353806  0.03540063]]
# Qs : [[1.7619393  0.07371435]]
# Qs : [[1.626883   0.15786637]]
# Qs : [[1.4572848  0.31097922]]
# Qs : [[1.4516828  0.49530402]]
# Qs : [[0.49836212 1.4506221 ]]
# Qs : [[0.4994717 1.4500595]]
# Qs : [[-100.            0.49978215]]
# Episode : 68, steps : 9
# Episode 68 train done, See our trained network in action.
# Total score : 10.0
# Qs : [[1.8760872  0.01059645]]
# Qs : [[0.97333026 1.8510108 ]]
# Qs : [[1.796968   0.05489329]]
# Qs : [[1.6934077  0.11546918]]
# Qs : [[1.5502137  0.23118891]]
# Qs : [[1.4542525  0.39057392]]
# Qs : [[0.49530312 1.4523911 ]]
# Qs : [[0.49713707 1.4517927 ]]
# Qs : [[0.49784982 1.4518052 ]]
# Qs : [[   0.49776572 -100.        ]]
# Episode : 69, steps : 10
# Episode 69 train done, See our trained network in action.
# Total score : 10.0
# Qs : [[1.8685613  0.01258302]]
# Qs : [[0.96524096 1.8303089 ]]
# Qs : [[0.92262775 1.7433065 ]]
# Qs : [[1.5770596  0.17457037]]
# Qs : [[1.4532597 0.3588802]]
# Qs : [[0.49660978 1.4509441 ]]
# Qs : [[0.4990725 1.4501089]]
# Qs : [[0.49998945 1.4501537 ]]
# Qs : [[-100.            0.49970898]]
# Episode : 70, steps : 9
# Episode 70 train done, See our trained network in action.
# Total score : 9.0
# Qs : [[1.8731514  0.01142999]]
# Qs : [[1.8436184  0.02977251]]
# Qs : [[1.7789036  0.06252027]]
# Qs : [[1.6587307  0.13425188]]
# Qs : [[1.5017518  0.26739794]]
# Qs : [[1.452654   0.44116467]]
# Qs : [[0.49689695 1.4520895 ]]
# Qs : [[0.49730507 1.4529579 ]]
# Qs : [[0.4963257 1.455208 ]]
# Qs : [[   0.49380744 -100.        ]]
# Episode : 71, steps : 10
# Episode 71 train done, See our trained network in action.
# Total score : 8.0
# Qs : [[1.8709121  0.01108114]]
# Qs : [[1.8364326  0.03203183]]
# Qs : [[1.7592012  0.06999971]]
# Qs : [[1.6127989  0.15499426]]
# Qs : [[1.4523834  0.31663233]]
# Qs : [[1.4509548  0.49618495]]
# Qs : [[0.4990389 1.4500414]]
# Qs : [[1.4500694  0.49994832]]
# Qs : [[   0.500431 -100.      ]]
# Episode : 72, steps : 9
# Episode 72 train done, See our trained network in action.
# Total score : 11.0
# Qs : [[1.8703429  0.01209325]]
# Qs : [[1.8348004  0.03259311]]
# Qs : [[1.7552509  0.07167666]]
# Qs : [[1.626265   0.15924308]]
# Qs : [[1.4586352  0.30136752]]
# Qs : [[1.4506397  0.48839384]]
# Qs : [[1.4516462  0.49914357]]
# Qs : [[1.452661  0.4980298]]
# Qs : [[-100.           0.4969035]]
# Episode : 73, steps : 9
# Episode 73 train done, See our trained network in action.
# Total score : 10.0
# Qs : [[1.8751794  0.00839199]]
# Qs : [[1.8423305  0.02730057]]
# Qs : [[1.7643197  0.06346022]]
# Qs : [[1.6064373  0.14941278]]
# Qs : [[1.4513988 0.3236611]]
# Qs : [[0.49818283 1.4501439 ]]
# Qs : [[0.49996996 1.4505789 ]]
# Qs : [[-100.            0.49955028]]
# Episode : 74, steps : 8
# Episode 74 train done, See our trained network in action.
# Total score : 9.0
# Qs : [[1.8841577  0.00589201]]
# Qs : [[1.8645676  0.01741522]]
# Qs : [[1.8184733  0.03899157]]
# Qs : [[1.7160401  0.08977652]]
# Qs : [[1.5563898  0.20275553]]
# Qs : [[1.4551412  0.37895623]]
# Qs : [[0.49396873 1.4535049 ]]
# Qs : [[0.49579164 1.4534608 ]]
# Qs : [[   0.49584138 -100.        ]]
# Episode : 75, steps : 9
# Episode 75 train done, See our trained network in action.
# Total score : 10.0
# Qs : [[1.8863835  0.00544152]]
# Qs : [[1.8707906 0.014933 ]]
# Qs : [[1.8359681 0.0320788]]
# Qs : [[1.7678131  0.07040106]]
# Qs : [[1.6589516  0.14550129]]
# Qs : [[1.4936638 0.265461 ]]
# Qs : [[1.4536263  0.44795036]]
# Qs : [[0.49608353 1.4530668 ]]
# Qs : [[0.49670005 1.4525225 ]]
# Qs : [[   0.49728888 -100.        ]]
# Episode : 76, steps : 10
# Episode 76 train done, See our trained network in action.
# Total score : 9.0
# Qs : [[1.8847193  0.00560851]]
# Qs : [[1.8663203  0.01673013]]
# Qs : [[1.8248779  0.03693391]]
# Qs : [[1.7501855  0.08250154]]
# Qs : [[1.6275022  0.16470446]]
# Qs : [[1.4641213  0.30002812]]
# Qs : [[1.4502361  0.48245358]]
# Qs : [[1.4507198  0.49998903]]
# Qs : [[1.4517441  0.49893114]]
# Qs : [[-100.            0.49779868]]
# Episode : 77, steps : 10
# Episode 77 train done, See our trained network in action.
# Total score : 9.0
# Qs : [[1.8866613  0.00480943]]
# Qs : [[1.8693403  0.01460992]]
# Qs : [[1.8280151  0.03361772]]
# Qs : [[1.7439973  0.07901724]]
# Qs : [[1.609012   0.17143269]]
# Qs : [[0.68000555 1.4527453 ]]
# Qs : [[1.4504875  0.49674353]]
# Qs : [[0.49933213 1.450017  ]]
# Qs : [[   0.49988422 -100.        ]]
# Episode : 78, steps : 9
# Episode 78 train done, See our trained network in action.
# Total score : 9.0
# Qs : [[1.8854707  0.00466945]]
# Qs : [[1.8645599  0.01601924]]
# Qs : [[1.8125511  0.03910625]]
# Qs : [[1.6942729  0.09657235]]
# Qs : [[1.5244164  0.22742553]]
# Qs : [[1.4508768 0.4153319]]
# Qs : [[1.4517788 0.4988389]]
# Qs : [[-100.            0.49784148]]
# Episode : 79, steps : 8
# Episode 79 train done, See our trained network in action.
# Total score : 10.0
# Qs : [[1.8912691  0.00295027]]
# Qs : [[1.8795118  0.00957068]]
# Qs : [[1.8504776  0.02248189]]
# Qs : [[1.7795492  0.05440435]]
# Qs : [[1.656918   0.13247739]]
# Qs : [[1.4797184 0.2675223]]
# Qs : [[1.4503008  0.46362168]]
# Qs : [[1.4501473  0.50047296]]
# Qs : [[-100.            0.49996853]]
# Episode : 80, steps : 9
# Episode 80 train done, See our trained network in action.
# Total score : 8.0
# Qs : [[1.8915644  0.00310534]]
# Qs : [[1.881282   0.00921565]]
# Qs : [[1.8550317  0.02046927]]
# Qs : [[1.8068713  0.04922439]]
# Qs : [[0.89804405 1.7144983 ]]
# Qs : [[1.5562984  0.20480078]]
# Qs : [[1.454036   0.37915128]]
# Qs : [[0.49513412 1.4532973 ]]
# Qs : [[0.49606478 1.4531461 ]]
# Qs : [[   0.49623144 -100.        ]]
# Episode : 81, steps : 10
# Episode 81 train done, See our trained network in action.
# Total score : 9.0
# Qs : [[1.8919432  0.00276923]]
# Qs : [[1.8810928  0.00885505]]
# Qs : [[1.853575   0.02079134]]
# Qs : [[1.7975273  0.05108639]]
# Qs : [[1.6942725  0.11275212]]
# Qs : [[1.5292999  0.22639419]]
# Qs : [[1.4523151  0.40822297]]
# Qs : [[0.49757257 1.4518855 ]]
# Qs : [[   0.49803647 -100.        ]]
# Episode : 82, steps : 9
# Episode 82 train done, See our trained network in action.
# Total score : 9.0
# Qs : [[1.8947141e+00 1.6012015e-03]]
# Qs : [[1.8871413  0.00577077]]
# Qs : [[1.8669416 0.0140593]]
# Qs : [[1.8138127  0.03620311]]
# Qs : [[1.6959131  0.09453721]]
# Qs : [[1.5209711  0.22422743]]
# Qs : [[1.4508584  0.41702315]]
# Qs : [[1.4516598  0.49875283]]
# Qs : [[-100.            0.49789152]]
# Episode : 83, steps : 9
# Episode 83 train done, See our trained network in action.
# Total score : 10.0
# Qs : [[1.8942691  0.00193273]]
# Qs : [[1.8866948  0.00624742]]
# Qs : [[1.8682019  0.01452673]]
# Qs : [[1.8323493 0.0347571]]
# Qs : [[1.764159   0.07393447]]
# Qs : [[1.6404763  0.14869176]]
# Qs : [[1.4734907  0.28422645]]
# Qs : [[1.4500837  0.47058603]]
# Qs : [[1.450404  0.4999964]]
# Qs : [[   0.5003434 -100.       ]]
# Episode : 84, steps : 10
# Episode 84 train done, See our trained network in action.
# Total score : 10.0
# Qs : [[0.9985448 1.895128 ]]
# Qs : [[1.8881948  0.00530513]]
# Qs : [[1.8697934  0.01287638]]
# Qs : [[1.8245746  0.03299324]]
# Qs : [[1.7404964  0.08245149]]
# Qs : [[1.590996   0.17478879]]
# Qs : [[1.451714 0.338995]]
# Qs : [[1.4525934  0.49789384]]
# Qs : [[   0.50309175 -100.        ]]
# Episode : 85, steps : 9
# Episode 85 train done, See our trained network in action.
# Total score : 10.0
# Qs : [[1.8959734e+00 1.1435220e-03]]
# Qs : [[1.8899974  0.00436633]]
# Qs : [[1.8741053  0.01086685]]
# Qs : [[1.8318809  0.02818226]]
# Qs : [[1.744762   0.07418656]]
# Qs : [[1.5944666  0.16913976]]
# Qs : [[1.4553301  0.33451506]]
# Qs : [[0.50620127 1.4561539 ]]
# Qs : [[-100.            0.49292374]]
# Episode : 86, steps : 9
# Episode 86 train done, See our trained network in action.
# Total score : 8.0
# Qs : [[1.8976791e+00 6.9829723e-04]]
# Qs : [[1.8946536  0.00251449]]
# Qs : [[1.8870147  0.00580388]]
# Qs : [[1.8700976  0.01412081]]
# Qs : [[1.8386528  0.03256888]]
# Qs : [[1.7692722  0.06669962]]
# Qs : [[1.6373181  0.14214863]]
# Qs : [[1.4684172  0.28562447]]
# Qs : [[1.455278   0.47462994]]
# Qs : [[-100.            0.49412993]]
# Episode : 87, steps : 10
# Episode 87 train done, See our trained network in action.
# Total score : 10.0
# Qs : [[1.897474e+00 6.758158e-04]]
# Qs : [[1.8938093  0.00273197]]
# Qs : [[1.884133  0.0067142]]
# Qs : [[1.8594584  0.01725014]]
# Qs : [[1.8133359  0.04416493]]
# Qs : [[1.7148677  0.09441967]]
# Qs : [[1.5447761  0.20172158]]
# Qs : [[1.4527373  0.38801867]]
# Qs : [[1.4530686  0.49718162]]
# Qs : [[-100.            0.49676397]]
# Episode : 88, steps : 10
# Episode 88 train done, See our trained network in action.
# Total score : 10.0
# Qs : [[1.8982573e+00 4.6059425e-04]]
# Qs : [[1.8956012e+00 1.8788411e-03]]
# Qs : [[1.8878796  0.00475608]]
# Qs : [[1.8662918  0.01314111]]
# Qs : [[1.8197182 0.0366192]]
# Qs : [[1.7171056  0.08726433]]
# Qs : [[1.5397284  0.19887672]]
# Qs : [[-100.            0.39297435]]
# Episode : 89, steps : 8
# Episode 89 train done, See our trained network in action.
# Total score : 10.0
# Qs : [[1.8970326e+00 8.4039028e-04]]
# Qs : [[1.8885108  0.00435135]]
# Qs : [[1.8519559  0.01697729]]
# Qs : [[1.7161286  0.07056972]]
# Qs : [[1.4518187 0.2602754]]
# Qs : [[0.4988253 1.4503267]]
# Qs : [[0.49957788 1.4503522 ]]
# Qs : [[   0.49947917 -100.        ]]
# Episode : 90, steps : 8
# Episode 90 train done, See our trained network in action.
# Total score : 9.0
# Qs : [[1.8930604e+00 1.6198007e-03]]
# Qs : [[1.87311    0.00859084]]
# Qs : [[1.79058    0.03339481]]
# Qs : [[1.5263621 0.1355579]]
# Qs : [[1.4502169  0.44516176]]
# Qs : [[1.4507172 0.499569 ]]
# Qs : [[1.4507256 0.4990486]]
# Qs : [[1.4502118 0.4991076]]
# Qs : [[-100.            0.49964622]]
# Episode : 91, steps : 9
# Episode 91 train done, See our trained network in action.
# Total score : 10.0
# Qs : [[1.8807245 0.0042274]]
# Qs : [[1.8275673  0.02222786]]
# Qs : [[1.6338754  0.08347137]]
# Qs : [[1.4503766  0.30460298]]
# Qs : [[0.4995451 1.4500937]]
# Qs : [[0.49999037 1.4509279 ]]
# Qs : [[1.4521466 0.5012877]]
# Qs : [[0.49737427 1.4532337 ]]
# Qs : [[   0.49616283 -100.        ]]
# Episode : 92, steps : 9
# Episode 92 train done, See our trained network in action.
# Total score : 9.0
# Qs : [[1.8829921  0.00374803]]
# Qs : [[1.8395995 0.0190943]]
# Qs : [[1.6820548  0.06782591]]
# Qs : [[1.4510955  0.24443291]]
# Qs : [[0.4989077 1.4503571]]
# Qs : [[1.4501481 0.4994793]]
# Qs : [[1.450642   0.49966615]]
# Qs : [[0.49946305 1.4511873 ]]
# Qs : [[0.49885246 1.4517231 ]]
# Qs : [[   0.49824813 -100.        ]]
# Episode : 93, steps : 10
# Episode 93 train done, See our trained network in action.
# Total score : 10.0
# Qs : [[1.881373  0.0037041]]
# Qs : [[1.8267435  0.02070427]]
# Qs : [[1.6242611  0.08146333]]
# Qs : [[1.4515837  0.30654845]]
# Qs : [[1.45247  0.498024]]
# Qs : [[1.4528596  0.49702626]]
# Qs : [[1.4527758  0.49654686]]
# Qs : [[1.452739   0.49660492]]
# Qs : [[-100.          0.496647]]
# Episode : 94, steps : 9
# Episode 94 train done, See our trained network in action.
# Total score : 10.0
# Qs : [[1.8839017  0.00319688]]
# Qs : [[1.8354988  0.01784792]]
# Qs : [[1.6461314  0.07155009]]
# Qs : [[1.45203    0.28174314]]
# Qs : [[1.4526592 0.497834 ]]
# Qs : [[0.5028747 1.4527636]]
# Qs : [[1.4522464  0.49702886]]
# Qs : [[1.4517548 0.4976088]]
# Qs : [[-100.            0.49814844]]
# Episode : 95, steps : 9
# Episode 95 train done, See our trained network in action.
# Total score : 10.0
# Qs : [[1.8849282  0.00289808]]
# Qs : [[1.8409022  0.01669708]]
# Qs : [[1.6690583  0.06551577]]
# Qs : [[1.4502833  0.25614282]]
# Qs : [[1.4510767  0.49989295]]
# Qs : [[1.4505002 0.4990012]]
# Qs : [[1.4504346 0.4997045]]
# Qs : [[0.49926248 1.4513042 ]]
# Qs : [[   0.49829656 -100.        ]]
# Episode : 96, steps : 9
# Episode 96 train done, See our trained network in action.
# Total score : 9.0
# Qs : [[1.878545   0.00379601]]
# Qs : [[0.97627074 1.8158593 ]]
# Qs : [[0.9067382 1.5927967]]
# Qs : [[1.4506451  0.34136552]]
# Qs : [[1.4511557  0.49919164]]
# Qs : [[1.4507987 0.4986177]]
# Qs : [[1.4503584  0.49898127]]
# Qs : [[1.450067  0.4994695]]
# Qs : [[-100.            0.49994117]]
# Episode : 97, steps : 9
# Episode 97 train done, See our trained network in action.
# Total score : 10.0
# Qs : [[1.8866777  0.00243874]]
# Qs : [[1.8458127  0.01479694]]
# Qs : [[1.6796556  0.06015974]]
# Qs : [[1.450334  0.2445035]]
# Qs : [[0.49949202 1.4506376 ]]
# Qs : [[1.4502424  0.49942175]]
# Qs : [[0.49956173 1.45114   ]]
# Qs : [[1.4519964 0.501438 ]]
# Qs : [[   0.49761838 -100.        ]]
# Episode : 98, steps : 9
# Episode 98 train done, See our trained network in action.
# Total score : 10.0
# Qs : [[1.8838016  0.00294558]]
# Qs : [[1.8363657  0.01793163]]
# Qs : [[1.6519377  0.07045425]]
# Qs : [[1.4502264  0.27478215]]
# Qs : [[1.4510123 0.4996397]]
# Qs : [[1.4507635  0.49875203]]
# Qs : [[1.4502977  0.49898657]]
# Qs : [[1.450109  0.4995037]]
# Qs : [[-100.            0.49995527]]
# Episode : 99, steps : 9
# Episode 99 train done, See our trained network in action.
# Total score : 11.0

# %%
print("Random greedy : 1 = random action, 0 = model predict")
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 2))
plt.scatter(range(len(aRandomList)), aRandomList, color="blue")
plt.show()
# Out:
# Random greedy : 1 = random action, 0 = model predict

# %%
print("Step count of each episode")
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 2))
plt.plot(range(len(rList)), rList, color="blue")
plt.show()
# Out:
# Step count of each episode

# %%
print("Test score of each episode")
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 2))
plt.plot(range(len(rList1)), rList1, color="blue")
plt.show()
# Out:
# Test score of each episode

# %%
env.close()

# %% [markdown]
# # 결과
# https://www.inflearn.com/course/reinforcement-learning/lecture/5791
# - converge 가 잘 되지 않음
#  - co-relation ?
#  - too shallow ?
# - 해법은 ?
#  - DQN
#    - deep network
#    - 버퍼에 쌓아놨다가 랜덤 샘플링을 해서 미니 배치로 학습 (*)
#    - 네트웍을 분리 & 중간중간 네트웍 복사
